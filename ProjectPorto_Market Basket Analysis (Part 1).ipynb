# %% [markdown]
# # Impor packages

# %%
# pip install pandas
# pip install numpy
# pip install datetime
import pandas as pd
import numpy as np
import datetime as dt

# %%
import os
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# # Impor data dari CSV ke DataFrame

# %%
df = pd.read_csv('Salinan Salinan Salinan Online Retail Data.csv', header=0)
df
# Out:
#        order_id product_code                     product_name  quantity  \
# 0        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 298726   525085        22189          CREAM HEART CARD HOLDER         2
# 298727   525086        20725          LUNCH BAG RED RETROSPOT         5
# 298728   525086        20727          LUNCH BAG  BLACK SKULL.         4
# 298729   525086       85099C   JUMBO  BAG BAROQUE BLACK WHITE        10
# 298730   525086        22382        LUNCH BAG SPACEBOY DESIGN         2
#
#                  order_date  price  customer_id
# 0       2010-01-04 09:24:00   4.50      12346.0
# 1       2010-01-04 09:43:00   4.25      14590.0
# 2       2010-01-04 09:53:00   4.50      12346.0
# 3       2010-01-04 09:54:00   0.85          NaN
# 4       2010-01-04 09:54:00   3.75          NaN
# ...                     ...    ...          ...
# 298726  2010-10-03 15:55:00   3.95      15884.0
# 298727  2010-10-03 15:55:00   1.65      16809.0
# 298728  2010-10-03 15:55:00   1.65      16809.0
# 298729  2010-10-03 15:55:00   1.95      16809.0
# 298730        2010-10-03 15    NaN          NaN
#
# [298731 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298731 entries, 0 to 298730
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      298731 non-null  object
#  1   product_code  298731 non-null  object
#  2   product_name  296606 non-null  object
#  3   quantity      298731 non-null  int64
#  4   order_date    298731 non-null  object
#  5   price         298730 non-null  float64
#  6   customer_id   237589 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 16.0+ MB

# %% [markdown]
# # Data cleansing

# %%
from scipy import stats

df_clean = df.copy()
# membuat kolom date
df_clean['date'] = pd.to_datetime(df_clean['order_date'], format='mixed', errors='coerce').dt.date.astype('datetime64[ns]')
# menghapus semua baris tanpa customer_id
df_clean = df_clean[~df_clean['customer_id'].isna()]
# mengkonversi customer_id menjadi string
df_clean['customer_id'] = df_clean['customer_id'].astype(str)
# menghapus semua baris tanpa product_name
df_clean = df_clean[~df_clean['product_name'].isna()]
# membuat semua product_name berhuruf kecil
df_clean['product_name'] = df_clean['product_name'].str.lower()
# menghapus semua baris dengan product_code atau product_name test
df_clean = df_clean[(~df_clean['product_code'].str.lower().str.contains('test')) |
                    (~df_clean['product_name'].str.contains('test '))]
# menghapus baris dengan status cancelled, yaitu yang order_id-nya diawali 'C'
df_clean = df_clean[df_clean['order_id'].str[:1]!='C']
# mengubah nilai quantity yang negatif menjadi positif karena nilai negatif tersebut hanya menandakan order tersebut cancelled
df_clean['quantity'] = df_clean['quantity'].abs()
# menghapus baris dengan price bernilai negatif
df_clean = df_clean[df_clean['price']>0]
# membuat nilai amount, yaitu perkalian antara quantity dan price
df_clean['amount'] = df_clean['quantity'] * df_clean['price']
# mengganti product_name dari product_code yang memiliki beberapa product_name dengan salah satu product_name-nya yang paling sering muncul
most_freq_product_name = df_clean.groupby(['product_code','product_name'], as_index=False).agg(order_cnt=('order_id','nunique')).sort_values(['product_code','order_cnt'], ascending=[True,False])
most_freq_product_name['rank'] = most_freq_product_name.groupby('product_code')['order_cnt'].rank(method='first', ascending=False)
most_freq_product_name = most_freq_product_name[most_freq_product_name['rank']==1].drop(columns=['order_cnt','rank'])
df_clean = df_clean.merge(most_freq_product_name.rename(columns={'product_name':'most_freq_product_name'}), how='left', on='product_code')
df_clean['product_name'] = df_clean['most_freq_product_name']
df_clean = df_clean.drop(columns='most_freq_product_name')
# menghapus outlier
from scipy import stats
df_clean = df_clean[(np.abs(stats.zscore(df_clean[['quantity','amount']]))<3).all(axis=1)]
df_clean = df_clean.reset_index(drop=True)
df_clean
# Out:
# <ipython-input-12-359740507786>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['customer_id'] = df_clean['customer_id'].astype(str)
#        order_id product_code                      product_name  quantity  \
# 0        493414        21844                 red retrospot mug        36
# 1        493414        21533         retro spot large milk jug        12
# 2        493414        37508   new england ceramic cake server         2
# 3        493414       35001G              hand open shape gold         2
# 4        493414        21527  red retrospot traditional teapot        12
# ...         ...          ...                               ...       ...
# 229936   525084        84879     assorted colour bird ornament        16
# 229937   525085        22189           cream heart card holder         2
# 229938   525086        20725              lunch bag red spotty         5
# 229939   525086        20727           lunch bag  black skull.         4
# 229940   525086       85099C    jumbo  bag baroque black white        10
#
#                  order_date  price customer_id       date  amount
# 0       2010-01-04 10:28:00   2.55     14590.0 2010-01-04   91.80
# 1       2010-01-04 10:28:00   4.25     14590.0 2010-01-04   51.00
# 2       2010-01-04 10:28:00   2.55     14590.0 2010-01-04    5.10
# 3       2010-01-04 10:28:00   4.25     14590.0 2010-01-04    8.50
# 4       2010-01-04 10:28:00   6.95     14590.0 2010-01-04   83.40
# ...                     ...    ...         ...        ...     ...
# 229936  2010-10-03 15:53:00   1.69     13883.0 2010-10-03   27.04
# 229937  2010-10-03 15:55:00   3.95     15884.0 2010-10-03    7.90
# 229938  2010-10-03 15:55:00   1.65     16809.0 2010-10-03    8.25
# 229939  2010-10-03 15:55:00   1.65     16809.0 2010-10-03    6.60
# 229940  2010-10-03 15:55:00   1.95     16809.0 2010-10-03   19.50
#
# [229941 rows x 9 columns]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229941 entries, 0 to 229940
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      229941 non-null  object
#  1   product_code  229941 non-null  object
#  2   product_name  229941 non-null  object
#  3   quantity      229941 non-null  int64
#  4   order_date    229941 non-null  object
#  5   price         229941 non-null  float64
#  6   customer_id   229941 non-null  object
#  7   date          229941 non-null  datetime64[ns]
#  8   amount        229941 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 15.8+ MB

# %% [markdown]
# # Menyiapkan data basket

# %% [markdown]
# ## Buat DataFrame basket

# %%
basket = pd.pivot_table(df_clean, index='order_id', columns='product_name', values='product_code', aggfunc='nunique', fill_value=0)
basket
# Out:
# product_name  10 colour spaceboy pen  12 ass zinc christmas decorations  \
# order_id
# 493414                             0                                  0
# 493427                             0                                  0
# 493428                             0                                  0
# 493432                             0                                  0
# 493433                             0                                  0
# ...                              ...                                ...
# 525082                             0                                  0
# 525083                             0                                  0
# 525084                             0                                  0
# 525085                             0                                  0
# 525086                             0                                  0
#
# product_name  12 coloured party balloons  12 daisy pegs in wood box  \
# order_id
# 493414                                 0                          0
# 493427                                 0                          0
# 493428                                 0                          0
# 493432                                 0                          0
# 493433                                 0                          0
# ...                                  ...                        ...
# 525082                                 0                          0
# 525083                                 0                          0
# 525084                                 0                          0
# 525085                                 0                          0
# 525086                                 0                          0
#
# product_name  12 egg house painted wood  12 ivory rose peg place settings  \
# order_id
# 493414                                0                                 0
# 493427                                0                                 0
# 493428                                0                                 0
# 493432                                0                                 0
# 493433                                0                                 0
# ...                                 ...                               ...
# 525082                                0                                 0
# 525083                                0                                 0
# 525084                                0                                 0
# 525085                                0                                 0
# 525086                                0                                 0
#
# product_name  12 message cards with envelopes  12 mini toadstool pegs  \
# order_id
# 493414                                      0                       0
# 493427                                      0                       0
# 493428                                      0                       0
# 493432                                      0                       0
# 493433                                      0                       0
# ...                                       ...                     ...
# 525082                                      0                       0
# 525083                                      0                       0
# 525084                                      0                       0
# 525085                                      0                       0
# 525086                                      0                       0
#
# product_name  12 pencil small tube woodland  12 pencils small tube posy  ...  \
# order_id                                                                 ...
# 493414                                    0                           0  ...
# 493427                                    0                           0  ...
# 493428                                    0                           0  ...
# 493432                                    0                           0  ...
# 493433                                    0                           0  ...
# ...                                     ...                         ...  ...
# 525082                                    0                           0  ...
# 525083                                    0                           0  ...
# 525084                                    0                           0  ...
# 525085                                    0                           0  ...
# 525086                                    0                           0  ...
#
# product_name  zinc heart lattice charger large  \
# order_id
# 493414                                       0
# 493427                                       0
# 493428                                       0
# 493432                                       0
# 493433                                       0
# ...                                        ...
# 525082                                       0
# 525083                                       0
# 525084                                       0
# 525085                                       0
# 525086                                       0
#
# product_name  zinc heart lattice charger small  \
# order_id
# 493414                                       0
# 493427                                       0
# 493428                                       0
# 493432                                       0
# 493433                                       0
# ...                                        ...
# 525082                                       0
# 525083                                       0
# 525084                                       0
# 525085                                       0
# 525086                                       0
#
# product_name  zinc heart lattice double planter  \
# order_id
# 493414                                        0
# 493427                                        0
# 493428                                        0
# 493432                                        0
# 493433                                        0
# ...                                         ...
# 525082                                        0
# 525083                                        0
# 525084                                        0
# 525085                                        0
# 525086                                        0
#
# product_name  zinc heart lattice planter bowl  \
# order_id
# 493414                                      0
# 493427                                      0
# 493428                                      0
# 493432                                      0
# 493433                                      0
# ...                                       ...
# 525082                                      0
# 525083                                      0
# 525084                                      0
# 525085                                      0
# 525086                                      0
#
# product_name  zinc heart lattice t-light holder  zinc heart lattice tray oval  \
# order_id
# 493414                                        0                             0
# 493427                                        0                             0
# 493428                                        0                             0
# 493432                                        0                             0
# 493433                                        0                             0
# ...                                         ...                           ...
# 525082                                        0                             0
# 525083                                        0                             0
# 525084                                        0                             0
# 525085                                        0                             0
# 525086                                        0                             0
#
# product_name  zinc metal heart decoration  zinc police box lantern  \
# order_id
# 493414                                  0                        0
# 493427                                  0                        0
# 493428                                  0                        0
# 493432                                  0                        0
# 493433                                  0                        0
# ...                                   ...                      ...
# 525082                                  0                        0
# 525083                                  0                        0
# 525084                                  0                        0
# 525085                                  0                        0
# 525086                                  0                        0
#
# product_name  zinc top  2 door wooden shelf  zinc willie winkie  candle stick
# order_id
# 493414                                    0                                 0
# 493427                                    0                                 0
# 493428                                    0                                 0
# 493432                                    0                                 0
# 493433                                    0                                 0
# ...                                     ...                               ...
# 525082                                    0                                 0
# 525083                                    0                                 0
# 525084                                    0                                 0
# 525085                                    0                                 0
# 525086                                    0                                 0
#
# [10931 rows x 3643 columns]

# %%
basket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10931 entries, 493414 to 525086
# Columns: 3643 entries, 10 colour spaceboy pen to zinc willie winkie  candle stick
# dtypes: int64(3643)
# memory usage: 303.9+ MB

# %% [markdown]
# ## Encode DataFrame basket dengan nilai True untuk semua nilai di atas 0 dan False untuk semua nilai 0

# %%
def encode(x):
    if x==0:
        return False
    if x>0:
        return True

basket_encode = basket.applymap(encode)
basket_encode
# Out:
# <ipython-input-16-31958d44448d>:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   basket_encode = basket.applymap(encode)
# product_name  10 colour spaceboy pen  12 ass zinc christmas decorations  \
# order_id
# 493414                         False                              False
# 493427                         False                              False
# 493428                         False                              False
# 493432                         False                              False
# 493433                         False                              False
# ...                              ...                                ...
# 525082                         False                              False
# 525083                         False                              False
# 525084                         False                              False
# 525085                         False                              False
# 525086                         False                              False
#
# product_name  12 coloured party balloons  12 daisy pegs in wood box  \
# order_id
# 493414                             False                      False
# 493427                             False                      False
# 493428                             False                      False
# 493432                             False                      False
# 493433                             False                      False
# ...                                  ...                        ...
# 525082                             False                      False
# 525083                             False                      False
# 525084                             False                      False
# 525085                             False                      False
# 525086                             False                      False
#
# product_name  12 egg house painted wood  12 ivory rose peg place settings  \
# order_id
# 493414                            False                             False
# 493427                            False                             False
# 493428                            False                             False
# 493432                            False                             False
# 493433                            False                             False
# ...                                 ...                               ...
# 525082                            False                             False
# 525083                            False                             False
# 525084                            False                             False
# 525085                            False                             False
# 525086                            False                             False
#
# product_name  12 message cards with envelopes  12 mini toadstool pegs  \
# order_id
# 493414                                  False                   False
# 493427                                  False                   False
# 493428                                  False                   False
# 493432                                  False                   False
# 493433                                  False                   False
# ...                                       ...                     ...
# 525082                                  False                   False
# 525083                                  False                   False
# 525084                                  False                   False
# 525085                                  False                   False
# 525086                                  False                   False
#
# product_name  12 pencil small tube woodland  12 pencils small tube posy  ...  \
# order_id                                                                 ...
# 493414                                False                       False  ...
# 493427                                False                       False  ...
# 493428                                False                       False  ...
# 493432                                False                       False  ...
# 493433                                False                       False  ...
# ...                                     ...                         ...  ...
# 525082                                False                       False  ...
# 525083                                False                       False  ...
# 525084                                False                       False  ...
# 525085                                False                       False  ...
# 525086                                False                       False  ...
#
# product_name  zinc heart lattice charger large  \
# order_id
# 493414                                   False
# 493427                                   False
# 493428                                   False
# 493432                                   False
# 493433                                   False
# ...                                        ...
# 525082                                   False
# 525083                                   False
# 525084                                   False
# 525085                                   False
# 525086                                   False
#
# product_name  zinc heart lattice charger small  \
# order_id
# 493414                                   False
# 493427                                   False
# 493428                                   False
# 493432                                   False
# 493433                                   False
# ...                                        ...
# 525082                                   False
# 525083                                   False
# 525084                                   False
# 525085                                   False
# 525086                                   False
#
# product_name  zinc heart lattice double planter  \
# order_id
# 493414                                    False
# 493427                                    False
# 493428                                    False
# 493432                                    False
# 493433                                    False
# ...                                         ...
# 525082                                    False
# 525083                                    False
# 525084                                    False
# 525085                                    False
# 525086                                    False
#
# product_name  zinc heart lattice planter bowl  \
# order_id
# 493414                                  False
# 493427                                  False
# 493428                                  False
# 493432                                  False
# 493433                                  False
# ...                                       ...
# 525082                                  False
# 525083                                  False
# 525084                                  False
# 525085                                  False
# 525086                                  False
#
# product_name  zinc heart lattice t-light holder  zinc heart lattice tray oval  \
# order_id
# 493414                                    False                         False
# 493427                                    False                         False
# 493428                                    False                         False
# 493432                                    False                         False
# 493433                                    False                         False
# ...                                         ...                           ...
# 525082                                    False                         False
# 525083                                    False                         False
# 525084                                    False                         False
# 525085                                    False                         False
# 525086                                    False                         False
#
# product_name  zinc metal heart decoration  zinc police box lantern  \
# order_id
# 493414                              False                    False
# 493427                              False                    False
# 493428                              False                    False
# 493432                              False                    False
# 493433                              False                    False
# ...                                   ...                      ...
# 525082                              False                    False
# 525083                              False                    False
# 525084                              False                    False
# 525085                              False                    False
# 525086                              False                    False
#
# product_name  zinc top  2 door wooden shelf  zinc willie winkie  candle stick
# order_id
# 493414                                False                             False
# 493427                                False                             False
# 493428                                False                             False
# 493432                                False                             False
# 493433                                False                             False
# ...                                     ...                               ...
# 525082                                False                             False
# 525083                                False                             False
# 525084                                False                             False
# 525085                                False                             False
# 525086                                False                             False
#
# [10931 rows x 3643 columns]

# %%
basket_encode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10931 entries, 493414 to 525086
# Columns: 3643 entries, 10 colour spaceboy pen to zinc willie winkie  candle stick
# dtypes: bool(3643)
# memory usage: 38.1+ MB

# %% [markdown]
# ## Ambil transaksi dengan banyaknya produk unik lebih dari 1 saja

# %%
basket_filter = basket_encode[(basket_encode>0).sum(axis=1)>1]
basket_filter
# Out:
# product_name  10 colour spaceboy pen  12 ass zinc christmas decorations  \
# order_id
# 493414                         False                              False
# 493427                         False                              False
# 493428                         False                              False
# 493432                         False                              False
# 493433                         False                              False
# ...                              ...                                ...
# 525081                         False                              False
# 525082                         False                              False
# 525083                         False                              False
# 525084                         False                              False
# 525086                         False                              False
#
# product_name  12 coloured party balloons  12 daisy pegs in wood box  \
# order_id
# 493414                             False                      False
# 493427                             False                      False
# 493428                             False                      False
# 493432                             False                      False
# 493433                             False                      False
# ...                                  ...                        ...
# 525081                             False                      False
# 525082                             False                      False
# 525083                             False                      False
# 525084                             False                      False
# 525086                             False                      False
#
# product_name  12 egg house painted wood  12 ivory rose peg place settings  \
# order_id
# 493414                            False                             False
# 493427                            False                             False
# 493428                            False                             False
# 493432                            False                             False
# 493433                            False                             False
# ...                                 ...                               ...
# 525081                            False                             False
# 525082                            False                             False
# 525083                            False                             False
# 525084                            False                             False
# 525086                            False                             False
#
# product_name  12 message cards with envelopes  12 mini toadstool pegs  \
# order_id
# 493414                                  False                   False
# 493427                                  False                   False
# 493428                                  False                   False
# 493432                                  False                   False
# 493433                                  False                   False
# ...                                       ...                     ...
# 525081                                  False                   False
# 525082                                  False                   False
# 525083                                  False                   False
# 525084                                  False                   False
# 525086                                  False                   False
#
# product_name  12 pencil small tube woodland  12 pencils small tube posy  ...  \
# order_id                                                                 ...
# 493414                                False                       False  ...
# 493427                                False                       False  ...
# 493428                                False                       False  ...
# 493432                                False                       False  ...
# 493433                                False                       False  ...
# ...                                     ...                         ...  ...
# 525081                                False                       False  ...
# 525082                                False                       False  ...
# 525083                                False                       False  ...
# 525084                                False                       False  ...
# 525086                                False                       False  ...
#
# product_name  zinc heart lattice charger large  \
# order_id
# 493414                                   False
# 493427                                   False
# 493428                                   False
# 493432                                   False
# 493433                                   False
# ...                                        ...
# 525081                                   False
# 525082                                   False
# 525083                                   False
# 525084                                   False
# 525086                                   False
#
# product_name  zinc heart lattice charger small  \
# order_id
# 493414                                   False
# 493427                                   False
# 493428                                   False
# 493432                                   False
# 493433                                   False
# ...                                        ...
# 525081                                   False
# 525082                                   False
# 525083                                   False
# 525084                                   False
# 525086                                   False
#
# product_name  zinc heart lattice double planter  \
# order_id
# 493414                                    False
# 493427                                    False
# 493428                                    False
# 493432                                    False
# 493433                                    False
# ...                                         ...
# 525081                                    False
# 525082                                    False
# 525083                                    False
# 525084                                    False
# 525086                                    False
#
# product_name  zinc heart lattice planter bowl  \
# order_id
# 493414                                  False
# 493427                                  False
# 493428                                  False
# 493432                                  False
# 493433                                  False
# ...                                       ...
# 525081                                  False
# 525082                                  False
# 525083                                  False
# 525084                                  False
# 525086                                  False
#
# product_name  zinc heart lattice t-light holder  zinc heart lattice tray oval  \
# order_id
# 493414                                    False                         False
# 493427                                    False                         False
# 493428                                    False                         False
# 493432                                    False                         False
# 493433                                    False                         False
# ...                                         ...                           ...
# 525081                                    False                         False
# 525082                                    False                         False
# 525083                                    False                         False
# 525084                                    False                         False
# 525086                                    False                         False
#
# product_name  zinc metal heart decoration  zinc police box lantern  \
# order_id
# 493414                              False                    False
# 493427                              False                    False
# 493428                              False                    False
# 493432                              False                    False
# 493433                              False                    False
# ...                                   ...                      ...
# 525081                              False                    False
# 525082                              False                    False
# 525083                              False                    False
# 525084                              False                    False
# 525086                              False                    False
#
# product_name  zinc top  2 door wooden shelf  zinc willie winkie  candle stick
# order_id
# 493414                                False                             False
# 493427                                False                             False
# 493428                                False                             False
# 493432                                False                             False
# 493433                                False                             False
# ...                                     ...                               ...
# 525081                                False                             False
# 525082                                False                             False
# 525083                                False                             False
# 525084                                False                             False
# 525086                                False                             False
#
# [10066 rows x 3643 columns]

# %%
basket_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10066 entries, 493414 to 525086
# Columns: 3643 entries, 10 colour spaceboy pen to zinc willie winkie  candle stick
# dtypes: bool(3643)
# memory usage: 35.0+ MB
